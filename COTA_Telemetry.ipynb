# %%
import numpy as np
import pandas as pd #To read the dataset
import time
from IPython import display
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.animation as animation
from matplotlib.colors import LogNorm
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('KyMa_S1000RR_20171029_011.csv')
data = data[:1620]
points = data.as_matrix(['Distance', 'GPS_Speed'])

dataset.head()
# Out:
#    Time  Distance  Internal Batte  Vertical_acc  Longitudinal_a  Lateral_acc  \
# 0   0.0     0.000           4.169      1.288091       -0.123282     0.003711
# 1   0.1     0.022           4.169      1.141163       -0.218517     0.002015
# 2   0.2     0.045           4.169      0.947527       -0.409658     0.006668
# 3   0.3     0.067           4.169      0.800068       -0.573618     0.008480
# 4   0.4     0.090           4.169      0.737422       -0.566797     0.007098
#
#    External Batte           RPM        TPS  BANKING     ...        CornerG  \
# 0       14.180549  13313.349609  51.396000    -8.74     ...       0.087332
# 1       14.180948  12944.599609  27.903999    -9.63     ...       0.098262
# 2       14.181349  12568.500000   8.500000    -9.00     ...       0.104591
# 3       14.181748  12874.299805   8.648000    -8.63     ...       0.102730
# 4       14.182149  12758.750000   8.752001    -8.00     ...       0.090436
#
#    Acceleration    TotalG  LeanAngleGPS  LeanAngleDataMC  LeanAngleECU  \
# 0      0.121746  0.087332     -1.663606        -4.990935      1.577491
# 1      0.108590  0.105804     -1.673375        -5.611898      1.940414
# 2      0.154438  0.154438     -1.641607        -5.970906      2.229481
# 3      0.242858  0.242858     -1.574522        -5.865326      2.674824
# 4      0.343874  0.343874     -1.483905        -5.167118      2.681565
#
#    GPS_Latitude  GPS_Longitude  GPS_Elevation  Unnamed: 65
# 0     30.131669     -97.639615         151.67          NaN
# 1     30.131631     -97.639559         151.79          NaN
# 2     30.131593     -97.639503         151.92          NaN
# 3     30.131555     -97.639447         152.08          NaN
# 4     30.131517     -97.639392         152.28          NaN
#
# [5 rows x 66 columns]

# %%
plt.scatter(points[:,0], points[:,1])
plt.show()
